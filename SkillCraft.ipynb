# %% [markdown]
# <a href="https://colab.research.google.com/github/S-SufiyaMoosa/SCT_DS_1/blob/main/SkillCraft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_2586629.csv')

# %%
df.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
df.tail()
# Out:
#     Country Code                      Region          IncomeGroup  \
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes     TableName  \
# 260                                                NaN        Kosovo
# 261  The World Bank systematically assesses the app...   Yemen, Rep.
# 262  Fiscal year end: March 31; reporting period fo...  South Africa
# 263  National accounts data were rebased to reflect...        Zambia
# 264  National Accounts data are reported in Zimbabw...      Zimbabwe
#
#      Unnamed: 5
# 260         NaN
# 261         NaN
# 262         NaN
# 263         NaN
# 264         NaN

# %%
plt.figure(figsize=(12, 6))

# %%
plt.subplot(1, 2, 1)
india_gender_counts = {gender: india_genders.count(gender) for gender in set(india_genders)}
plt.bar(india_gender_counts.keys(), india_gender_counts.values(), color=['blue', 'pink'])
plt.title('Gender Distribution in India')
plt.xlabel('Gender')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.subplot(1, 2, 2)
plt.hist(india_ages, bins=10, color='green', edgecolor='black')
plt.title('Age Distribution in India')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
df.isnull()
# Out:
#      Country Code  Region  IncomeGroup  SpecialNotes  TableName  Unnamed: 5
# 0           False   False        False          True      False        True
# 1           False    True         True         False      False        True
# 2           False   False        False         False      False        True
# 3           False    True         True         False      False        True
# 4           False   False        False         False      False        True
# ..            ...     ...          ...           ...        ...         ...
# 260         False   False        False          True      False        True
# 261         False   False        False         False      False        True
# 262         False   False        False         False      False        True
# 263         False   False        False         False      False        True
# 264         False   False        False         False      False        True
#
# [265 rows x 6 columns]

# %%
df.shape
# Out:
# (265, 6)
